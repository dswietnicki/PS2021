# %% [markdown]
# <a href="https://colab.research.google.com/github/dswietnicki/PS2021/blob/main/Sprawko1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sympy.solvers import solve
from sympy import Symbol
from sympy import cos, pi, sin
import sympy
import math

minimumOmega = 1
maksimumOmega = 100
omegaS = 1
omegaD = 10

alpha = 1.0/1.795

results = list()

for bOmega in range(minimumOmega, maksimumOmega, omegaS):
    omega = bOmega / omegaD
    print("omega = " + str(omega))
    def q(t): 
        (alpha * math.sin(omega * t) - omega * math.cos(omega * t))/(omega**2 + alpha**2)
    
    tSym = Symbol('tSym')
    qDerSolutions = solve([alpha*sympy.cos(omega*tSym) + omega*sympy.sin(omega*tSym), tSym >= 0, tSym <= 2*pi/omega], tSym)
    print("q punkty ekstremum: " + str(qDerSolutions))
    
    extremeQValues = list()
    for solution in qDerSolutions:
        extremeQValues.append(q(solution))
    print(extremeQValues)
    
    minimumQValue = min(extremeQValues)
    maksimumQValue = max(extremeQValues)
    amplitude = maksimumQValue - minimumQValue
    results.append((omega, amplitude))

#nie kompiluje się
# Out:
# omega = 0.1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     209
# --> 210                         monom[indices[base]] = exp
#     211                     except KeyError:
#
# KeyError: cos(0.1*_tSym)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     814     try:
# --> 815         p = Poly(expr, s)
#     816         if p.degree() == 0:
#
# /usr/local/lib/python3.7/dist-packages/sympy/polys/polytools.py in __new__(cls, rep, *gens, **args)
#     161             else:
# --> 162                 return cls._from_expr(rep, opt)
#     163
#
# ...
